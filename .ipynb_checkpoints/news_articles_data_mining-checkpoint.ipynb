# %% [markdown]
# # News Articles Data Mining Notebook

# %% [markdown]
# In this notebook we are going to deal with data from various news articles of diggerent kinds(business,
# entertainment, politics, sport and tech). We are going to create wordclouds, and perform classification and clustering for our data.

# %% [markdown]
# ## Import Libraries

# %%
# Ignoring unnecessory warnings
import warnings
warnings.filterwarnings("ignore")  
# Specialized container datatypes
import collections
# For Map vizualization
import folium
from nltk.corpus import genesis
# For data vizualization 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# For large and multi-dimensional arrays
import numpy as np
# For data manipulation and analysis
import pandas as pd
# Natural language processing library
import nltk
nltk.download('genesis')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import gensim
from gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import STOPWORDS
# For image processing
from PIL import Image, ImageOps
# For random selection 
import random
# For basic cleaning and data preprocessing 
import re
import string 
# Communicating with operating and file system
import os
# Machine learning libary
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.externals import joblib
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support 
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, normalize, label_binarize
from sklearn.svm import SVC
# For wordcloud generating 
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package genesis to
# [nltk_data]     /Users/pantelis/nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pantelis/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pantelis/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Create and load datasets

# %% [markdown]
# Given a directory with all the data, we create 2 different data frames; one for training our algorithms, and one for testing. We use a python script that we created, and can be found in the parent directory of the project

# %%
# %run create_dataset.py --dir data --out data/dataset.tsv
TRAIN_DATASET = "./data/train_set.tsv"
TEST_DATASET = "./data/test_set.tsv"
train_df = pd.read_csv(TRAIN_DATASET, sep='\t')
test_df = pd.read_csv(TEST_DATASET, sep='\t')
# Out:
# ---------------------- Constructing dataset ----------------------
#
# Running with the following configuration
# 	 dir --> data
# 	 out --> data/dataset.tsv
#
# Creating datasets...
# 	An error occured on reading file: /Users/pantelis/Desktop/News-Articles-Classification/data/sport/199.txt
# Datasets creating completed successfully. Time elapsed: 0.331 seconds

# %% [markdown]
# Let's look at the dataset info to see if everything is alright.

# %%
train_df.info()
train_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1779 entries, 0 to 1778
# Data columns (total 4 columns):
# Id          1779 non-null int64
# Title       1779 non-null object
# Content     1779 non-null object
# Category    1779 non-null object
# dtypes: int64(1), object(3)
# memory usage: 55.7+ KB
#      Id                                Title  \
# 0  1056    Davenport hits out at Wimbledon\n
# 1   161  Arnold congratulated on Oscar win\n
# 2   783   Axa Sun Life cuts bonus payments\n
# 3  1402   Real will finish abandoned match\n
# 4  2054           Media gadgets get moving\n
#
#                                              Content       Category
# 0  \nWorld number one Lindsay Davenport has criti...          sport
# 1  \nOscar-winner Andrea Arnold has been congratu...  entertainment
# 2  \nLife insurer Axa Sun Life has lowered annual...       business
# 3  \nReal Madrid and Real Socieded will play the ...          sport
# 4  \nPocket-sized devices that let people carry a...           tech

# %%
test_df.info()
test_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 4 columns):
# Id          445 non-null int64
# Title       445 non-null object
# Content     445 non-null object
# Category    445 non-null object
# dtypes: int64(1), object(3)
# memory usage: 14.0+ KB
#      Id                                Title  \
# 0  1107                   Italy 8-38 Wales\n
# 1  1350             Leeds v Saracens (Fri)\n
# 2  1709  Terror detainees win Lords appeal\n
# 3   197  Singer Knight backs anti-gun song\n
# 4   635  Ban on forced retirement under 65\n
#
#                                              Content       Category
# 0  \nWales secured their first away win in the RB...          sport
# 1  \nHeadingley\n\nFriday, 25 February\n\n2000 GM...          sport
# 2  \nDetaining foreign terrorist suspects without...       politics
# 3  \nR&B star Beverley Knight said she sang on an...  entertainment
# 4  \nEmployers will no longer be able to force wo...       business

# %% [markdown]
# ## 1. Wordclouds

# %% [markdown]
# We are going to create one wordcloud for each category

# %% [markdown]
# ### Business articles

# %%
maskImageArray = np.array(Image.open("wordcloud_masks/business.png"))
stop_words = nltk.corpus.stopwords.words('english')
business_wordcloud = WordCloud(max_words=1000,mask=maskImageArray, background_color="white", stopwords=stop_words).generate(' '.join(train_df.loc[train_df['Category'] == 'business']['Content'].tolist()))
plt.imshow(business_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Entertainment articles

# %%
maskImageArray = np.array(Image.open("wordcloud_masks/entairtenment.png"))
stop_words = nltk.corpus.stopwords.words('english')
ent_wordcloud = WordCloud(max_words=1000,mask=maskImageArray, background_color="white", stopwords=stop_words).generate(' '.join(train_df.loc[train_df['Category'] == 'entertainment']['Content'].tolist()))
plt.imshow(ent_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Politics articles

# %%
maskImageArray = np.array(Image.open("wordcloud_masks/politics.png"))
stop_words = nltk.corpus.stopwords.words('english')
pol_wordcloud = WordCloud(max_words=1000,mask=maskImageArray, background_color="white", stopwords=stop_words).generate(' '.join(train_df.loc[train_df['Category'] == 'politics']['Content'].tolist()))
plt.imshow(pol_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Sports articles

# %%
maskImageArray = np.array(Image.open("wordcloud_masks/sports.png"))
stop_words = nltk.corpus.stopwords.words('english')
sport_wordcloud = WordCloud(max_words=1000,mask=maskImageArray, background_color="white", stopwords=stop_words).generate(' '.join(train_df.loc[train_df['Category'] == 'sport']['Content'].tolist()))
plt.imshow(sport_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Tech articles

# %%
maskImageArray = np.array(Image.open("wordcloud_masks/tech.png"))
stop_words = nltk.corpus.stopwords.words('english')
tech_wordcloud = WordCloud(max_words=1000,mask=maskImageArray, background_color="white", stopwords=stop_words).generate(' '.join(train_df.loc[train_df['Category'] == 'tech']['Content'].tolist()))
plt.imshow(tech_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 2. Classification

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# Firstly, we have to preprocess our training and test set. We have to consider preprocessing on both title and content columns in order to have homogenous preprocessed data.

# %%
 def text_normalization(text):
    # convert text to lowercase
    text = text.lower()
    # remove all special characters, punctuation and spaces from string
    text = re.sub(r'\W+',' ', text)
    # remove stop words
    removed = remove_stopwords(text)
    text = "".join(removed)
    # Perform lemamatization
    lemmatizer = WordNetLemmatizer()
    lem_sentence = []
    token_words = word_tokenize(text)
    lem_sentence = [lemmatizer.lemmatize(word) for word in token_words]
    text = " ".join(lem_sentence)
    # return normalized text
    return text

# %%
def preprocess(input_df):
    # Remove rows with missing values in column col
    input_df.dropna(inplace=True)
    # Speed up code using numpy vectorization
    vfunc = np.vectorize(text_normalization)
    input_df.Title = vfunc(input_df.Title.values)
    input_df.Content = vfunc(input_df.Content.values)
    # return processed input_df
    return input_df

# %% [markdown]
# Let's apply the above preprocessing techniques on training set

# %%
preprocessed_train_df = preprocess(train_df)

# %%
preprocessed_train_df.insert(3, "Description", 
                             preprocessed_train_df['Title'] + ' ' + preprocessed_train_df['Content'], 
                             True)

# %%
preprocessed_train_df.head()
# Out:
#      Id                           Title  \
# 0  1056         davenport hit wimbledon
# 1   161  arnold congratulated oscar win
# 2   783  axa sun life cut bonus payment
# 3  1402     real finish abandoned match
# 4  2054            medium gadget moving
#
#                                              Content  \
# 0  world number lindsay davenport criticised wimb...
# 1  oscar winner andrea arnold congratulated uk fi...
# 2  life insurer axa sun life lowered annual bonus...
# 3  real madrid real socieded play final minute ma...
# 4  pocket sized device let people carry video ima...
#
#                                          Description       Category
# 0  davenport hit wimbledon world number lindsay d...          sport
# 1  arnold congratulated oscar win oscar winner an...  entertainment
# 2  axa sun life cut bonus payment life insurer ax...       business
# 3  real finish abandoned match real madrid real s...          sport
# 4  medium gadget moving pocket sized device let p...           tech

# %% [markdown]
# Let's apply now the above preprocessing techniques on test set

# %%
preprocessed_test_df = preprocess(test_df)

# %%
preprocessed_test_df.insert(3, "Description", 
                             preprocessed_test_df['Title'] + ' ' + preprocessed_test_df['Content'], 
                             True)

# %%
preprocessed_test_df.head()
# Out:
#      Id                             Title  \
# 0  1107                   italy 8 38 wale
# 1  1350               leeds v saracen fri
# 2  1709   terror detainee win lord appeal
# 3   197  singer knight back anti gun song
# 4   635          ban forced retirement 65
#
#                                              Content  \
# 0  wale secured away win rb nation nearly year tr...
# 1  headingley friday 25 february 2000 gmt tyke br...
# 2  detaining foreign terrorist suspect trial brea...
# 3  r b star beverley knight said sang anti gun si...
# 4  employer longer able force worker retire 65 ju...
#
#                                          Description       Category
# 0  italy 8 38 wale wale secured away win rb natio...          sport
# 1  leeds v saracen fri headingley friday 25 febru...          sport
# 2  terror detainee win lord appeal detaining fore...       politics
# 3  singer knight back anti gun song r b star beve...  entertainment
# 4  ban forced retirement 65 employer longer able ...       business

# %% [markdown]
# ### Base Classifier

# %% [markdown]
# Below, we introduce a base classifier class which will be used from each classifier in order to inherit the steps of prediction pipeline. Also, kfold cross-validation is implemented there in an an abstract logic as well.

# %%
class Classifier:
    def __init__(self, classifier_name, train_df, test_df, feature):
        self.classifier_name = classifier_name
        self.feature = feature
        self.steps = []
        # Encode labels with value the different articles' categories
        self.le = LabelEncoder()
        self.le.fit(train_df['Category'])
        # define x_train and y_train
        self.x_train = train_df['Description']
        self.y_train = self.le.transform(train_df['Category'])
        # define x_test
        self.x_test = test_df['Description'] if not test_df is None else None
        self.y_test = self.le.transform(test_df['Category']) if not test_df is None else None

    def define_features(self):
        self.steps = []
        if self.feature == "TF-IDF":
            self.steps.append(('vect', TfidfVectorizer()))
        elif self.feature == "BoW":
            self.steps.append(('vect', CountVectorizer(stop_words='english')))            
        return self.steps

    def predict_kfold(self, pipeline):
        score_array = []
        accuracy_array = []
        # apply 10-fold cross validation
        kf = KFold(n_splits=10)
        for train_index, test_index in kf.split(self.x_train):
            # use iloc which is label based indexing
            cv_train_x = self.x_train.iloc[train_index]
            cv_test_x = self.x_train.iloc[test_index]
            cv_train_y = self.y_train[train_index]
            cv_test_y = self.y_train[test_index]
            # fit model
            pipeline.fit(cv_train_x, cv_train_y)
            if (self.classifier_name == "SVM"):
                print("Best parameters set found on development set:")
                print()
                print(pipeline.named_steps['clf'].best_params_)
                print()
                print("Grid scores on development set:")
                print()
                means = pipeline.named_steps['clf'].cv_results_['mean_test_score']
                stds = pipeline.named_steps['clf'].cv_results_['std_test_score']
                for mean, std, params in zip(means, stds, pipeline.named_steps['clf'].cv_results_['params']):
                    print("%0.3f (+/-%0.03f) for %r"
                          % (mean, std * 2, params))
                print()
            # predict label in form of numbers {0,1,2,3,4}
            predicted = pipeline.predict(cv_test_x) 
            # apply inverse transform to get labels
            y_labels = self.le.inverse_transform(cv_test_y)
            y_pred = self.le.inverse_transform(predicted)
            # append score and accuracy values to corresponding arrays
            score_array.append(precision_recall_fscore_support(y_labels, y_pred, average=None))
            accuracy_array.append(accuracy_score(y_labels, y_pred))                    
        # compute classification report metrics
        avg_accuracy = round(np.mean(accuracy_array), 4)
        avg_scores = np.mean(np.mean(score_array, axis=0), axis=1)
        avg_precision = round(avg_scores[0], 4)
        avg_recall = round(avg_scores[1], 4)
        avg_f1 = round(avg_scores[2], 4)
        return (avg_accuracy, avg_precision, avg_recall, avg_f1)
    
    def get_test_metrics(self, pipeline):
        y_pred = pipeline.predict(self.x_test)
        accuracy = accuracy_score(self.y_test, y_pred)
        precision, recall, f1, _ = precision_recall_fscore_support(self.y_test, y_pred, average='weighted')
        return accuracy, precision, recall, f1
        
    def plot_roc_auc(self, pipeline):
        classes = ['Business', 'Entertainment', 'Politics', 'Sport', 'Tech']
        scores = pipeline.predict_proba(self.x_test)
        y_test = label_binarize(self.y_test, classes=[0, 1, 2, 3, 4])
        y_pred = np.argmax(scores, axis=1)
        n_classes = y_test.shape[1]
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test[:, i], scores[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])
        colors = ['blue', 'red', 'green', 'orange', 'yellow']
        for i, color in zip(range(n_classes), colors):
            plt.plot(fpr[i], tpr[i], color=color,
                     label='ROC curve of class {0} (area = {1:0.4f})'
                     ''.format(classes[i], roc_auc[i]))

        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([-0.05, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic for multi-class data')
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
class SVM(Classifier):
    def __init__(self, train_df, test_df, feature):
        self.tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4], 'C': [1, 10, 100, 1000]},
                                 {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]
        Classifier.__init__(self, "SVM", train_df, test_df, feature)

    def define_features(self):
        steps = Classifier.define_features(self)
        steps.append(('clf', GridSearchCV(SVC(probability=True), self.tuned_parameters)))
        self.pipeline = Pipeline(steps)

    def run_kfold(self):
        self.define_features()
        return self.predict_kfold(self.pipeline)
    
    def evaluate(self):
        self.plot_roc_auc(self.pipeline)
        return self.get_test_metrics(self.pipeline)

# %% [markdown]
# #### Bag of Words featurization method

# %%
classifier = SVM(preprocessed_train_df, preprocessed_test_df, "BoW")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.952 (+/-0.013) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.751 (+/-0.023) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.962 (+/-0.012) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.955 (+/-0.016) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.962 (+/-0.012) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.014) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.962 (+/-0.012) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.014) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.014) for {'C': 1, 'kernel': 'linear'}
# 0.964 (+/-0.014) for {'C': 10, 'kernel': 'linear'}
# 0.964 (+/-0.014) for {'C': 100, 'kernel': 'linear'}
# 0.964 (+/-0.014) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.949 (+/-0.015) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.761 (+/-0.027) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.961 (+/-0.023) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.959 (+/-0.019) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.961 (+/-0.023) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.961 (+/-0.023) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.961 (+/-0.023) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.961 (+/-0.023) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.016) for {'C': 1, 'kernel': 'linear'}
# 0.963 (+/-0.016) for {'C': 10, 'kernel': 'linear'}
# 0.963 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.963 (+/-0.016) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.954 (+/-0.012) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.761 (+/-0.019) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.019) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.959 (+/-0.014) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.019) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.959 (+/-0.023) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.019) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.959 (+/-0.023) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.961 (+/-0.017) for {'C': 1, 'kernel': 'linear'}
# 0.961 (+/-0.017) for {'C': 10, 'kernel': 'linear'}
# 0.961 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.961 (+/-0.017) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.957 (+/-0.017) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.766 (+/-0.021) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.016) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.014) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.016) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.015) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.015) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.009) for {'C': 1, 'kernel': 'linear'}
# 0.964 (+/-0.009) for {'C': 10, 'kernel': 'linear'}
# 0.964 (+/-0.009) for {'C': 100, 'kernel': 'linear'}
# 0.964 (+/-0.009) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.951 (+/-0.026) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.761 (+/-0.029) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.021) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.962 (+/-0.020) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.021) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.968 (+/-0.016) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.021) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.968 (+/-0.016) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.970 (+/-0.012) for {'C': 1, 'kernel': 'linear'}
# 0.970 (+/-0.012) for {'C': 10, 'kernel': 'linear'}
# 0.970 (+/-0.012) for {'C': 100, 'kernel': 'linear'}
# 0.970 (+/-0.012) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.955 (+/-0.003) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.760 (+/-0.014) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.006) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.005) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.006) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.005) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.006) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.005) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.966 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.966 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.966 (+/-0.008) for {'C': 100, 'kernel': 'linear'}
# 0.966 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.956 (+/-0.005) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.767 (+/-0.019) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.010) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.008) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.010) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.965 (+/-0.006) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.010) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.965 (+/-0.006) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.967 (+/-0.002) for {'C': 1, 'kernel': 'linear'}
# 0.967 (+/-0.002) for {'C': 10, 'kernel': 'linear'}
# 0.967 (+/-0.002) for {'C': 100, 'kernel': 'linear'}
# 0.967 (+/-0.002) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.956 (+/-0.013) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.754 (+/-0.018) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.011) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.962 (+/-0.006) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.011) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.008) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.011) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.008) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.966 (+/-0.002) for {'C': 1, 'kernel': 'linear'}
# 0.966 (+/-0.002) for {'C': 10, 'kernel': 'linear'}
# 0.966 (+/-0.002) for {'C': 100, 'kernel': 'linear'}
# 0.966 (+/-0.002) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.961 (+/-0.014) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.756 (+/-0.022) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.017) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.966 (+/-0.009) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.017) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.965 (+/-0.008) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.964 (+/-0.017) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.965 (+/-0.008) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.967 (+/-0.005) for {'C': 1, 'kernel': 'linear'}
# 0.967 (+/-0.005) for {'C': 10, 'kernel': 'linear'}
# 0.967 (+/-0.005) for {'C': 100, 'kernel': 'linear'}
# 0.967 (+/-0.005) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.952 (+/-0.016) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.765 (+/-0.021) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.013) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.958 (+/-0.011) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.013) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.965 (+/-0.010) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.963 (+/-0.013) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.965 (+/-0.010) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.966 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.966 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.966 (+/-0.008) for {'C': 100, 'kernel': 'linear'}
# 0.966 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# 10-fold Cross Validation Accuracy: 96.91%
# 10-fold Cross Validation Precision: 96.87%
# 10-fold Cross Validation Recall: 96.78%
# 10-fold Cross Validation F1-Score: 96.78%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 98.43%
# Test set Precision: 98.43%
# Test set Recall: 98.43%
# Test set F1-Score: 98.43%

# %% [markdown]
# #### TF-IDF featurization method

# %%
classifier = SVM(preprocessed_train_df, preprocessed_test_df, "TF-IDF")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
# Out:
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.237 (+/-0.000) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.237 (+/-0.000) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.237 (+/-0.000) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.237 (+/-0.000) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.939 (+/-0.012) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.237 (+/-0.000) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.975 (+/-0.010) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.939 (+/-0.012) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.977 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.974 (+/-0.016) for {'C': 10, 'kernel': 'linear'}
# 0.974 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.974 (+/-0.016) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.227 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.939 (+/-0.029) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.976 (+/-0.013) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.939 (+/-0.029) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.976 (+/-0.012) for {'C': 1, 'kernel': 'linear'}
# 0.976 (+/-0.013) for {'C': 10, 'kernel': 'linear'}
# 0.976 (+/-0.013) for {'C': 100, 'kernel': 'linear'}
# 0.976 (+/-0.013) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.232 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.943 (+/-0.008) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.976 (+/-0.008) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.944 (+/-0.009) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.975 (+/-0.008) for {'C': 1, 'kernel': 'linear'}
# 0.976 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.976 (+/-0.008) for {'C': 100, 'kernel': 'linear'}
# 0.976 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.228 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.228 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.228 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.228 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.941 (+/-0.008) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.228 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.012) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.941 (+/-0.008) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.977 (+/-0.014) for {'C': 1, 'kernel': 'linear'}
# 0.977 (+/-0.016) for {'C': 10, 'kernel': 'linear'}
# 0.977 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.977 (+/-0.016) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.231 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.231 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.231 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.231 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.939 (+/-0.017) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.231 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.976 (+/-0.015) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.940 (+/-0.019) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.014) for {'C': 1, 'kernel': 'linear'}
# 0.974 (+/-0.018) for {'C': 10, 'kernel': 'linear'}
# 0.974 (+/-0.018) for {'C': 100, 'kernel': 'linear'}
# 0.974 (+/-0.018) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.232 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.944 (+/-0.009) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.979 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.944 (+/-0.009) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.017) for {'C': 1, 'kernel': 'linear'}
# 0.979 (+/-0.016) for {'C': 10, 'kernel': 'linear'}
# 0.979 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.979 (+/-0.016) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.227 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.940 (+/-0.021) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.227 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.011) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.940 (+/-0.021) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.009) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.014) for {'C': 10, 'kernel': 'linear'}
# 0.978 (+/-0.014) for {'C': 100, 'kernel': 'linear'}
# 0.978 (+/-0.014) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.232 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.933 (+/-0.013) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.232 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.011) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.933 (+/-0.013) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.011) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.012) for {'C': 10, 'kernel': 'linear'}
# 0.978 (+/-0.012) for {'C': 100, 'kernel': 'linear'}
# 0.978 (+/-0.012) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.234 (+/-0.000) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.234 (+/-0.000) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.234 (+/-0.000) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.234 (+/-0.000) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.943 (+/-0.017) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.234 (+/-0.000) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.975 (+/-0.007) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.943 (+/-0.017) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.011) for {'C': 1, 'kernel': 'linear'}
# 0.976 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.976 (+/-0.008) for {'C': 100, 'kernel': 'linear'}
# 0.976 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# Best parameters set found on development set:
#
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.230 (+/-0.001) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.230 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.230 (+/-0.001) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.230 (+/-0.001) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.937 (+/-0.013) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.230 (+/-0.001) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.978 (+/-0.011) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.937 (+/-0.013) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.976 (+/-0.015) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.011) for {'C': 10, 'kernel': 'linear'}
# 0.978 (+/-0.011) for {'C': 100, 'kernel': 'linear'}
# 0.978 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}

# %%
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 98.03%
# 10-fold Cross Validation Precision: 98.00%
# 10-fold Cross Validation Recall: 97.97%
# 10-fold Cross Validation F1-Score: 97.96%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 98.20%
# Test set Precision: 98.21%
# Test set Recall: 98.20%
# Test set F1-Score: 98.20%

# %% [markdown]
# ###  Random Forests

# %%
class RandomForest(Classifier):

    def __init__(self, train_df, test_df, feature):
        Classifier.__init__(self, "RF", train_df, test_df, feature)

    def define_features(self):
        steps = Classifier.define_features(self)
        steps.append(('clf', RandomForestClassifier(n_estimators = 100, criterion = 'entropy')))
        self.pipeline = Pipeline(steps)

    def run_kfold(self):
        self.define_features()
        return self.predict_kfold(self.pipeline)
    
    def evaluate(self):
        self.plot_roc_auc(self.pipeline)
        return self.get_test_metrics(self.pipeline)

# %% [markdown]
# #### Bag of Words featurization method

# %%
classifier = RandomForest(preprocessed_train_df, preprocessed_test_df, "BoW")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 95.90%
# 10-fold Cross Validation Precision: 96.11%
# 10-fold Cross Validation Recall: 95.62%
# 10-fold Cross Validation F1-Score: 95.78%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 95.96%
# Test set Precision: 95.98%
# Test set Recall: 95.96%
# Test set F1-Score: 95.95%

# %% [markdown]
# #### TF-IDF featurization method

# %%
classifier = RandomForest(preprocessed_train_df, preprocessed_test_df, "TF-IDF")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 96.12%
# 10-fold Cross Validation Precision: 96.36%
# 10-fold Cross Validation Recall: 95.87%
# 10-fold Cross Validation F1-Score: 96.04%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 96.40%
# Test set Precision: 96.43%
# Test set Recall: 96.40%
# Test set F1-Score: 96.40%

# %% [markdown]
# ### Naive Bayes

# %%
class NaiveBayes(Classifier):

    def __init__(self, train_df, test_df, feature):
        Classifier.__init__(self, "NB", train_df, test_df, feature)

    def define_features(self):
        steps = Classifier.define_features(self)
        steps.append(('clf', MultinomialNB()))
        self.pipeline = Pipeline(steps)

    def run_kfold(self):
        self.define_features()
        return self.predict_kfold(self.pipeline)
    
    def evaluate(self):
        self.plot_roc_auc(self.pipeline)
        return self.get_test_metrics(self.pipeline)

# %% [markdown]
# #### Bag of Words featurization method

# %%
classifier = NaiveBayes(preprocessed_train_df, preprocessed_test_df, "BoW")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 97.47%
# 10-fold Cross Validation Precision: 97.39%
# 10-fold Cross Validation Recall: 97.33%
# 10-fold Cross Validation F1-Score: 97.30%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 97.53%
# Test set Precision: 97.60%
# Test set Recall: 97.53%
# Test set F1-Score: 97.52%

# %% [markdown]
# #### TF-IDF featurization method

# %%
classifier = NaiveBayes(preprocessed_train_df, preprocessed_test_df, "TF-IDF")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 96.57%
# 10-fold Cross Validation Precision: 96.58%
# 10-fold Cross Validation Recall: 96.32%
# 10-fold Cross Validation F1-Score: 96.35%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 97.08%
# Test set Precision: 97.09%
# Test set Recall: 97.08%
# Test set F1-Score: 97.07%

# %% [markdown]
# ###  K-Nearest Neighbor

# %%
class KNeighborsClassifier(object):
    """ A kNN classifier with L2 distance """

    def __init__(self, n_neighbors=1):
        """
        Class constructor
        Inputs:
        - n_neighbors: Hyperparameter k for kNN Classifier - default is 1
        """
        self.k = n_neighbors

    def fit(self, X, y):
        """
        Fit the classifier. For k-nearest neighbors this is just
        memorizing the training data.
        Inputs:
        - X: A numpy array of shape (num_train, D) containing the training data
          consisting of num_train samples each of dimension D.
        - y: A numpy array of shape (N,) containing the training labels, where
             y[i] is the label for X[i].
        """
        self.X_train = X.toarray()
        self.y_train = y

    def predict(self, X):
        """
        Predict labels for test data using this classifier.
        Inputs:
        - X: A numpy array of shape (num_test, D) containing test data consisting
             of num_test samples each of dimension D.
        - k: The number of nearest neighbors that vote for the predicted labels.
        Returns:
        - y: A numpy array of shape (num_test,) containing predicted labels for the
          test data, where y[i] is the predicted label for the test point X[i].
        """
        return self.predict_labels(self.compute_distances(X.toarray()))
    
    def predict_proba(self, X):
        """
        Predict probabilities of each labels for test data using this classifier.
        Inputs:
        - X: A numpy array of shape (num_test, D) containing test data consisting
             of num_test samples each of dimension D.
        Returns:
        - y: A numpy array of shape (num_test, num_classes) containing predicted 
             probabilities of each label for the test data, where y[i] corresponds
             to test point X[i].
        """
        pass
        

    def compute_distances(self, X):
        """
        Compute the distance between each test point in X and each training point
        in self.X_train using no explicit loops.
         Inputs:
        - X: A numpy array of shape (num_test, D) containing test data.
        Returns:
        - dists: A numpy array of shape (num_test, num_train) where dists[i, j]
          is the Euclidean distance between the ith test point and the jth training
          point.
        """
        num_test = X.shape[0]
        num_train = self.X_train.shape[0]
        dists = np.zeros((num_test, num_train))
        #########################################################################
        # Compute the l2 distance between all test points and all training      #
        # points without using any explicit loops, and store the result in      #
        # dists.                                                                #
        #########################################################################
        test_square = np.sum(np.square(X), axis = 1).reshape(num_test, 1)
        train_square = np.sum(np.square(self.X_train), axis = 1).reshape(1, num_train)
        dists = np.sqrt(test_square + train_square - 2 * np.dot(X, self.X_train.T))

        return dists

    def predict_labels(self, dists):
        """
        Given a matrix of distances between test points and training points,
        predict a label for each test point.
        Inputs:
        - dists: A numpy array of shape (num_test, num_train) where dists[i, j]
          gives the distance betwen the ith test point and the jth training point.
        Returns:
        - y: A numpy array of shape (num_test,) containing predicted labels for the
          test data, where y[i] is the predicted label for the test point X[i].
        """
        num_test = dists.shape[0]
        y_pred = np.zeros(num_test)
        for i in range(num_test):
            # A list of length k storing the labels of the k nearest neighbors to
            # the ith test point.
            closest_y = []
            #########################################################################
            # Use the distance matrix to find the k nearest neighbors of the ith    #
            # testing point, and use self.y_train to find the labels of these       #
            # neighbors. Store these labels in closest_y.                           #
            #########################################################################
            min_idxs = np.argpartition(dists[i],self.k)[:self.k]
            for min_idx in min_idxs:
                closest_y.append(self.y_train[min_idx])
            #########################################################################
            # Now that you have found the labels of the k nearest neighbors, you    #
            # need to find the most common label in the list closest_y of labels.   #
            # Store this label in y_pred[i]. Break ties by choosing the smaller     #
            # label.                                                                #
            #########################################################################
            y_pred[i] = np.bincount(closest_y).argmax()

        return list(map(int, y_pred.tolist()))
    
    def predict_probabilities(self, dits):
        """
        Given a matrix of distances between test points and training points,
        predict probabilities of each label for every test point.
        Inputs:
        - dists: A numpy array of shape (num_test, num_train) where dists[i, j]
          gives the distance betwen the ith test point and the jth training point.
        Returns:
        - y: A numpy array of shape (num_test, num_classes) containing predicted 
             probabilities of each label for the test data, where y[i] corresponds
             to test point X[i].
        """
        pass

# %%
class KNN(Classifier):

    def __init__(self, train_df, test_df, feature):
        Classifier.__init__(self, "KNN", train_df, test_df, feature)

    def define_features(self):
        steps = Classifier.define_features(self)
        steps.append(('clf', KNeighborsClassifier()))
        self.pipeline = Pipeline(steps)

    def run_kfold(self):
        self.define_features()
        return self.predict_kfold(self.pipeline)
    
    def evaluate(self):
        return self.get_test_metrics(self.pipeline)

# %% [markdown]
# ####  Bag of Words featurization method

# %%
classifier = KNN(preprocessed_train_df, preprocessed_test_df, "BoW")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 71.56%
# 10-fold Cross Validation Precision: 80.09%
# 10-fold Cross Validation Recall: 70.94%
# 10-fold Cross Validation F1-Score: 71.88%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 72.58%
# Test set Precision: 81.77%
# Test set Recall: 72.58%
# Test set F1-Score: 73.50%

# %% [markdown]
# ####  TD-IDF featurization method

# %%
classifier = KNN(preprocessed_train_df, preprocessed_test_df, "TF-IDF")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 91.96%
# 10-fold Cross Validation Precision: 91.66%
# 10-fold Cross Validation Recall: 91.85%
# 10-fold Cross Validation F1-Score: 91.61%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 92.13%
# Test set Precision: 92.23%
# Test set Recall: 92.13%
# Test set F1-Score: 92.14%

# %% [markdown]
# ## 3. Beat the Benchmark

# %% [markdown]
# In order to beat the Benchmark we are going to use a Voting classifier model combines multiple different models (i.e., sub-estimators) into a single model, which is (ideally) stronger than any of the individual models alone.

# %%
class BeatTheBenchmark(Classifier):

    def __init__(self, train_df, test_df, feature):
        Classifier.__init__(self, "NB", train_df, test_df, feature)

    def define_features(self):
        steps = Classifier.define_features(self)
        
        clf1 = LogisticRegression(solver='lbfgs', multi_class='multinomial', max_iter=100, random_state=1)
        clf2 = RandomForestClassifier(n_estimators=100, criterion='entropy')
        clf3 = SVC(kernel='linear', probability=True)
        steps.append(('clf', VotingClassifier(estimators = [('lr', clf1), ('rf', clf2), ('svm', clf3)], voting='soft', weights=[4, 2, 5])))

        self.pipeline = Pipeline(steps)

    def run_kfold(self):
        self.define_features()
        return self.predict_kfold(self.pipeline)
    
    def evaluate(self):
        self.plot_roc_auc(self.pipeline)
        return self.get_test_metrics(self.pipeline)

# %%
classifier = BeatTheBenchmark(preprocessed_train_df, preprocessed_test_df, "BoW")

# %%
cv_accuracy, cv_precision, cv_recall, cv_f1 = classifier.run_kfold()
print("10-fold Cross Validation Accuracy: {:.2f}%".format(cv_accuracy * 100))
print("10-fold Cross Validation Precision: {:.2f}%".format(cv_precision * 100))
print("10-fold Cross Validation Recall: {:.2f}%".format(cv_recall * 100))
print("10-fold Cross Validation F1-Score: {:.2f}%".format(cv_f1 * 100))
# Out:
# 10-fold Cross Validation Accuracy: 97.25%
# 10-fold Cross Validation Precision: 97.21%
# 10-fold Cross Validation Recall: 97.15%
# 10-fold Cross Validation F1-Score: 97.14%

# %%
test_accuracy, test_precision, test_recall, test_f1 = classifier.evaluate()
print("Test set Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test set Precision: {:.2f}%".format(test_precision * 100))
print("Test set Recall: {:.2f}%".format(test_recall * 100))
print("Test set F1-Score: {:.2f}%".format(test_f1 * 100))
# Out:
# Test set Accuracy: 98.20%
# Test set Precision: 98.22%
# Test set Recall: 98.20%
# Test set F1-Score: 98.21%

# %% [markdown]
# As we can cleary see, we beated the benchmark!

# %% [markdown]
# ## 4. Clustering

# %% [markdown]
# ### BoW + PCA

# %%
X = CountVectorizer(stop_words='english').fit_transform(preprocessed_train_df['Description']).toarray()
pca = PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# We need only the calculated resulting components scores for the elements in our data set:

# %%
scores_pca = pca.transform(X)
print(scores_pca)
# Out:
# [[-1.0791266  -0.55434394  0.65931859]
#  [-3.27749488 -0.32844792  1.47184315]
#  [-2.6161897  -1.46380345 -1.05405113]
#  ...
#  [-1.84706013 -0.67005623  0.15046862]
#  [-1.98534718 -0.93650139 -2.05754836]
#  [-4.42622029  0.52568712  3.26039753]]

# %% [markdown]
# Let's now implement K-Means using #Category, aka 5, clusters

# %%
kmeans_pca = KMeans(n_clusters=5, init='k-means++', random_state=42)

# %%
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)

# %% [markdown]
# It's time now to analyze now PCA and K-Means results

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters
X_bow_pca_kmeans = pd.concat([pd.DataFrame(X), pd.DataFrame(scores_pca, columns=['Component {}'.format(i) for i in range(1,4)])], axis=1)
# The last column we add contains the pca k-means clusterin labels
X_bow_pca_kmeans['Segment K-means Pca'] = kmeans_pca.labels_

# %%
X_bow_pca_kmeans['Segment'] = X_bow_pca_kmeans['Segment K-means Pca'].map({
    0: 'Business',
    1: 'Entertainment',
    2: 'Politics',
    3: 'Sport',
    4: 'Tech'
})

# %%
# Plot data by PCA components. The Y-axis is the first component and the X-axis the second one
x_axis = X_bow_pca_kmeans['Component 2']
y_axis = X_bow_pca_kmeans['Component 1']
sns.scatterplot(x_axis, y_axis, hue = X_bow_pca_kmeans['Segment'])
plt.title('Clusters by BoW and PCA components')
plt.show()

# %% [markdown]
# #### TF-IDF + PCA

# %%
X = TfidfVectorizer().fit_transform(preprocessed_train_df['Description']).toarray()
pca = PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
scores_pca = pca.transform(X)
print(scores_pca)
# Out:
# [[-0.04702007 -0.09724698 -0.03611211]
#  [-0.13058644 -0.18922794  0.35910846]
#  [-0.00865655  0.06322341 -0.01412457]
#  ...
#  [-0.05356512 -0.05614047 -0.09636457]
#  [-0.01456644  0.15274172 -0.02709812]
#  [-0.14375473 -0.20429998  0.34259067]]

# %%
kmeans_pca = KMeans(n_clusters=5, init='k-means++', random_state=42)
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters
X_tfidf_pca_kmeans = pd.concat([pd.DataFrame(X), pd.DataFrame(scores_pca, columns=['Component {}'.format(i) for i in range(1,4)])], axis=1)
# The last column we add contains the pca k-means clusterin labels
X_tfidf_pca_kmeans['Segment K-means Pca'] = kmeans_pca.labels_

# %%
X_tfidf_pca_kmeans['Segment'] = X_tfidf_pca_kmeans['Segment K-means Pca'].map({
    0: 'Business',
    1: 'Entertainment',
    2: 'Politics',
    3: 'Sport',
    4: 'Tech'
})

# %%
# Plot data by PCA components. The Y-axis is the first component and the X-axis the second one
x_axis = X_tfidf_pca_kmeans['Component 2']
y_axis = X_tfidf_pca_kmeans['Component 1']
sns.scatterplot(x_axis, y_axis, hue = X_tfidf_pca_kmeans['Segment'])
plt.title('Clusters by TF-IDF and PCA components')
plt.show()

# %% [markdown]
# #### W2V + PCA

# %% [markdown]
# At first we have to train our word embeddings simple by using gensim Word2Vec model

# %%
sentences = []
for row in preprocessed_train_df['Description']:
    sentences.append(word_tokenize(row))
model = gensim.models.Word2Vec(sentences, min_count=1, size= 100, workers=3, window =3, sg = 1)

# %% [markdown]
# Right after let's compute the embedding vector of each sentences

# %%
X = model[model.wv.vocab]
pca = PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
scores_pca = pca.transform(X)
print(scores_pca)
# Out:
# [[ 0.8754461  -0.75881416  0.42409438]
#  [ 0.9547748  -0.7861165  -0.34229058]
#  [ 1.0145297  -1.093979    0.5942864 ]
#  ...
#  [-0.54262567  0.01303845  0.01154211]
#  [-0.53915095 -0.03167188  0.04150547]
#  [-0.58105326 -0.01620939 -0.01889106]]

# %%
kmeans_pca = KMeans(n_clusters=5, init='k-means++', random_state=42)
# We fit our data with the k-means pca model
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=42, tol=0.0001, verbose=0)

# %%
# We create a new data frame with the original features and add the PCA scores and assigned clusters
X_w2v_pca_kmeans = pd.concat([pd.DataFrame(X), pd.DataFrame(scores_pca, columns=['Component {}'.format(i) for i in range(1,4)])], axis=1)
# The last column we add contains the pca k-means clusterin labels
X_w2v_pca_kmeans['Segment K-means Pca'] = kmeans_pca.labels_

# %%
X_w2v_pca_kmeans['Segment'] = X_w2v_pca_kmeans['Segment K-means Pca'].map({
    0: 'Business',
    1: 'Entertainment',
    2: 'Politics',
    3: 'Sport',
    4: 'Tech'
})

# %%
# Plot data by PCA components. The Y-axis is the first component and the X-axis the second one
x_axis = X_w2v_pca_kmeans['Component 2']
y_axis = X_w2v_pca_kmeans['Component 1']
sns.scatterplot(x_axis, y_axis, hue = X_w2v_pca_kmeans['Segment'])
plt.title('Clusters by W2V and PCA components')
plt.show()
